# %%
from neo4j import GraphDatabase
import time
import json

# %%
class neo4jWriter:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        return

    ### Result Writer ###
    def resultWriter(self, filePath):
        with self.driver.session() as session:
            with open(filePath, 'r') as fileHandle:
                # go through and create all Node
                batchStr = '['
                batchCount = 0
                totalCount = 0
                line = fileHandle.readline()
                while line:
                    batchStr = batchStr + self.__resultLineToJSON(line) +', '
                    batchCount += 1
                    if batchCount == 1000:
                        batchStr = batchStr[:-2] + ']'
                        session.write_transaction(self.__createResultBatchTx, batchStr)
                        totalCount += batchCount
                        batchCount = 0
                        batchStr = '['
                        print('Result: Write a batch. %s nodes completed.' % totalCount)
                    line = fileHandle.readline()
                if batchCount > 0:
                    batchStr = batchStr[:-2] + ']'
                    session.write_transaction(self.__createResultBatchTx, batchStr)
                    totalCount += batchCount
                    print('Result: Write the last batch. %s nodes completed.' % totalCount)
                # create CenterAt Edges
                session.write_transaction(self.__createAllCNTx)
                print('Result: All Done')
        return totalCount
    def __resultLineToJSON(self, line):
        # {nodeId: $nid, commList: [$cid, $cid, ...]}
        items = line.split()
        jsonStr = '{nodeId: %s, commList: [' % items[0]
        for item in items[1:]:
            jsonStr = jsonStr + '{commId: %s}, ' % item
        jsonStr = jsonStr[:-2] + ']}'
        return jsonStr
    def __createResultBatchTx(self, tx, batch):
        cypher = 'UNWIND %s AS item MERGE (n:Node {nid:item.nodeId}) FOREACH (comm IN item.commList | \
                  MERGE (c:Community {cid:comm.commId}) CREATE (n)-[:BelongTo]->(c))' % batch
        result = tx.run(cypher)
        return result.consume()
    def __createAllCNTx(self, tx):
        cypher = 'MATCH (c:Community), (n:Node) WHERE c.cid=n.nid CREATE (c)-[:CenterAt]->(n)'
        result = tx.run(cypher)
        return result.consume()

    ### Network Writer ###
    def networkWriter(self, filePath, bidir):
        with self.driver.session() as session:
            with open(filePath, 'r') as fileHandle:
                print("Network: %s nodes and %s edges in total." % (fileHandle.readline()[:-1], fileHandle.readline()[:-1]))
                # go through and create all Node
                batchStr = '['
                batchCount = 0
                totalCount = 0
                line = fileHandle.readline()
                while line:
                    batchStr = batchStr + self.__networkLineToJSON(line) +', '
                    batchCount += 1
                    if batchCount == 2000:
                        batchStr = batchStr[:-2] + ']'
                        session.write_transaction(self.__createNetworkBatchTx, batchStr, bidir)
                        totalCount += batchCount
                        batchCount = 0
                        batchStr = '['
                        print('Network: Write a batch. %s edges completed.' % totalCount)
                    line = fileHandle.readline()
                if batchCount > 0:
                    batchStr = batchStr[:-2] + ']'
                    session.write_transaction(self.__createNetworkBatchTx, batchStr, bidir)
                    totalCount += batchCount
                    print('Network: Write the last batch. %s edges completed.' % totalCount)
                print('Network: All Done')
        return totalCount
    def __networkLineToJSON(self, line):
        # {nodeId1: $nid1, nodeId2: $nid2}
        nodeId1, nodeId2 = line.split()
        jsonStr = '{nodeId1: %s, nodeId2: %s}' % (nodeId1, nodeId2)
        return jsonStr
    def __createNetworkBatchTx(self, tx, batch, bidir):
        cypher = 'UNWIND %s AS item MERGE (n1:Node {nid:item.nodeId1}) \
                  MERGE (n2:Node {nid:item.nodeId2}) CREATE (n1)-[:Relation]->(n2)'
        if bidir:
            cypher = cypher + ', (n2)-[:Relation]->(n1)'
        result = tx.run(cypher % batch)
        return result.consume()

    ### Index Builder ###
    def indexBuilder(self):
        with self.driver.session() as session:
            session.write_transaction(self.__createIndexTx)
            print('Index: All Done')
        return
    def __createIndexTx(self, tx):
        # automatically create index when creating a unique constraint
        cypher = 'CREATE CONSTRAINT ON (n:Node) ASSERT n.nid IS UNIQUE'
        result = tx.run(cypher)
        result.consume()
        #cypher = 'CREATE INDEX ON :Node(nid)'
        #result = tx.run(cypher)
        #result.consume()
        
        # automatically create index when creating a unique constraint
        cypher = 'CREATE CONSTRAINT ON (c:Community) ASSERT c.cid IS UNIQUE'
        result = tx.run(cypher)
        result.consume()
        #cypher = 'CREATE INDEX ON :Community(cid)'
        #result = tx.run(cypher)
        #result.consume()
        return True

    ### Other Transactions(Abandoned) ###
    def __createNodeTx(self, tx, nodeId, nodeLabel, **nodeAttrs):
        cypher = 'CREATE (n: %s {nid: %s' % (nodeLabel, nodeId)
        if nodeAttrs:
            for item in nodeAttrs.items():
                cypher = cypher + ', %s: %s' % (item[0], item[1])
        cypher = cypher + '}) RETURN n'
        result = tx.run(cypher)
        return result.single()
    def __createRelTx(self, tx, nodeId1, nodeLabel1, nodeId2, nodeLabel2, relType, **relAttrs):
        cypher = 'MATCH (a:%s), (b:%s) WHERE a.nid = %s AND b.nid = %s CREATE (a)-[r: %s' % (nodeLabel1, nodeLabel2, nodeId1, nodeId2, relType)
        if relAttrs:
            cypher = cypher + ' {'
            for item in relAttrs.items():
                cypher = cypher + '%s: %s, ' % (item[0], item[1])
            cypher = cypher[:-2] + '}'
        cypher = cypher + ']->(b) RETURN r'
        result = tx.run(cypher)
        return result.single()
    def __matchNodeTx(self, tx, nodeId=None, nodeLabel=None, **nodeAttrs):
        cypher = 'match'
        if nodeLabel:
            cypher = cypher + ' (n:%s)' % nodeLabel
        else:
            cypher = cypher + ' (n)'
        if nodeId:
            cypher = cypher + ' where n.nid = %s' % nodeId
            if nodeAttrs:
                for item in nodeAttrs.items():
                    cypher = cypher + ' and %s = %s' % (item[0], item[1])
        else:
            if nodeAttrs:
                cypher = cypher + ' where' % nodeId
                for item in nodeAttrs.items():
                    cypher = cypher + ' %s = %s and' % (item[0], item[1])
                cypher = cypher[:-4]
        cypher = cypher + ' return n'
        result = tx.run(cypher)
        records = []
        for record in result:
            records.append(record['n'])
        return records

# %%
if __name__ == '__main__':
    startTime = time.time()
    with open('settings.json', 'r') as fileHandle:
        settings = json.load(fileHandle)
        uri = settings['Neo4j']['uri']
        user = settings['Neo4j']['user']
        password = settings['Neo4j']['password']
        networkFilePath = settings['NetworkFilePath']
        resultFilePath = settings['ResultFilePath']
    writer = neo4jWriter(uri, user, password)
    writer.indexBuilder()
    writer.networkWriter(networkFilePath, True)
    writer.resultWriter(resultFilePath)
    completeTime = time.time()
    print('Running Time: %.3fs' % (completeTime-startTime))
# Out:
# Index: All Done
# Network: 334863 nodes and 925872 edges in total.
# Network: Write a batch. 2000 edges completed.
# Network: Write a batch. 4000 edges completed.
# Network: Write a batch. 6000 edges completed.
# Network: Write a batch. 8000 edges completed.
# Network: Write a batch. 10000 edges completed.
# Network: Write a batch. 12000 edges completed.
# Network: Write a batch. 14000 edges completed.
# Network: Write a batch. 16000 edges completed.
# Network: Write a batch. 18000 edges completed.
# Network: Write a batch. 20000 edges completed.
# Network: Write a batch. 22000 edges completed.
# Network: Write a batch. 24000 edges completed.
# Network: Write a batch. 26000 edges completed.
# Network: Write a batch. 28000 edges completed.
# Network: Write a batch. 30000 edges completed.
# Network: Write a batch. 32000 edges completed.
# Network: Write a batch. 34000 edges completed.
# Network: Write a batch. 36000 edges completed.
# Network: Write a batch. 38000 edges completed.
# Network: Write a batch. 40000 edges completed.
# Network: Write a batch. 42000 edges completed.
# Network: Write a batch. 44000 edges completed.
# Network: Write a batch. 46000 edges completed.
# Network: Write a batch. 48000 edges completed.
# Network: Write a batch. 50000 edges completed.
# Network: Write a batch. 52000 edges completed.
# Network: Write a batch. 54000 edges completed.
# Network: Write a batch. 56000 edges completed.
# Network: Write a batch. 58000 edges completed.
# Network: Write a batch. 60000 edges completed.
# Network: Write a batch. 62000 edges completed.
# Network: Write a batch. 64000 edges completed.
# Network: Write a batch. 66000 edges completed.
# Network: Write a batch. 68000 edges completed.
# Network: Write a batch. 70000 edges completed.
# Network: Write a batch. 72000 edges completed.
# Network: Write a batch. 74000 edges completed.
# Network: Write a batch. 76000 edges completed.
# Network: Write a batch. 78000 edges completed.
# Network: Write a batch. 80000 edges completed.
# Network: Write a batch. 82000 edges completed.
# Network: Write a batch. 84000 edges completed.
# Network: Write a batch. 86000 edges completed.
# Network: Write a batch. 88000 edges completed.
# Network: Write a batch. 90000 edges completed.
# Network: Write a batch. 92000 edges completed.
# Network: Write a batch. 94000 edges completed.
# Network: Write a batch. 96000 edges completed.
# Network: Write a batch. 98000 edges completed.
# Network: Write a batch. 100000 edges completed.
# Network: Write a batch. 102000 edges completed.
# Network: Write a batch. 104000 edges completed.
# Network: Write a batch. 106000 edges completed.
# Network: Write a batch. 108000 edges completed.
# Network: Write a batch. 110000 edges completed.
# Network: Write a batch. 112000 edges completed.
# Network: Write a batch. 114000 edges completed.
# Network: Write a batch. 116000 edges completed.
# Network: Write a batch. 118000 edges completed.
# Network: Write a batch. 120000 edges completed.
# Network: Write a batch. 122000 edges completed.
# Network: Write a batch. 124000 edges completed.
# Network: Write a batch. 126000 edges completed.
# Network: Write a batch. 128000 edges completed.
# Network: Write a batch. 130000 edges completed.
# Network: Write a batch. 132000 edges completed.
# Network: Write a batch. 134000 edges completed.
# Network: Write a batch. 136000 edges completed.
# Network: Write a batch. 138000 edges completed.
# Network: Write a batch. 140000 edges completed.
# Network: Write a batch. 142000 edges completed.
# Network: Write a batch. 144000 edges completed.
# Network: Write a batch. 146000 edges completed.
# Network: Write a batch. 148000 edges completed.
# Network: Write a batch. 150000 edges completed.
# Network: Write a batch. 152000 edges completed.
# Network: Write a batch. 154000 edges completed.
# Network: Write a batch. 156000 edges completed.
# Network: Write a batch. 158000 edges completed.
# Network: Write a batch. 160000 edges completed.
# Network: Write a batch. 162000 edges completed.
# Network: Write a batch. 164000 edges completed.
# Network: Write a batch. 166000 edges completed.
# Network: Write a batch. 168000 edges completed.
# Network: Write a batch. 170000 edges completed.
# Network: Write a batch. 172000 edges completed.
# Network: Write a batch. 174000 edges completed.
# Network: Write a batch. 176000 edges completed.
# Network: Write a batch. 178000 edges completed.
# Network: Write a batch. 180000 edges completed.
# Network: Write a batch. 182000 edges completed.
# Network: Write a batch. 184000 edges completed.
# Network: Write a batch. 186000 edges completed.
# Network: Write a batch. 188000 edges completed.
# Network: Write a batch. 190000 edges completed.
# Network: Write a batch. 192000 edges completed.
# Network: Write a batch. 194000 edges completed.
# Network: Write a batch. 196000 edges completed.
# Network: Write a batch. 198000 edges completed.
# Network: Write a batch. 200000 edges completed.
# Network: Write a batch. 202000 edges completed.
# Network: Write a batch. 204000 edges completed.
# Network: Write a batch. 206000 edges completed.
# Network: Write a batch. 208000 edges completed.
# Network: Write a batch. 210000 edges completed.
# Network: Write a batch. 212000 edges completed.
# Network: Write a batch. 214000 edges completed.
# Network: Write a batch. 216000 edges completed.
# Network: Write a batch. 218000 edges completed.
# Network: Write a batch. 220000 edges completed.
# Network: Write a batch. 222000 edges completed.
# Network: Write a batch. 224000 edges completed.
# Network: Write a batch. 226000 edges completed.
# Network: Write a batch. 228000 edges completed.
# Network: Write a batch. 230000 edges completed.
# Network: Write a batch. 232000 edges completed.
# Network: Write a batch. 234000 edges completed.
# Network: Write a batch. 236000 edges completed.
# Network: Write a batch. 238000 edges completed.
# Network: Write a batch. 240000 edges completed.
# Network: Write a batch. 242000 edges completed.
# Network: Write a batch. 244000 edges completed.
# Network: Write a batch. 246000 edges completed.
# Network: Write a batch. 248000 edges completed.
# Network: Write a batch. 250000 edges completed.
# Network: Write a batch. 252000 edges completed.
# Network: Write a batch. 254000 edges completed.
# Network: Write a batch. 256000 edges completed.
# Network: Write a batch. 258000 edges completed.
# Network: Write a batch. 260000 edges completed.
# Network: Write a batch. 262000 edges completed.
# Network: Write a batch. 264000 edges completed.
# Network: Write a batch. 266000 edges completed.
# Network: Write a batch. 268000 edges completed.
# Network: Write a batch. 270000 edges completed.
# Network: Write a batch. 272000 edges completed.
# Network: Write a batch. 274000 edges completed.
# Network: Write a batch. 276000 edges completed.
# Network: Write a batch. 278000 edges completed.
# Network: Write a batch. 280000 edges completed.
# Network: Write a batch. 282000 edges completed.
# Network: Write a batch. 284000 edges completed.
# Network: Write a batch. 286000 edges completed.
# Network: Write a batch. 288000 edges completed.
# Network: Write a batch. 290000 edges completed.
# Network: Write a batch. 292000 edges completed.
# Network: Write a batch. 294000 edges completed.
# Network: Write a batch. 296000 edges completed.
# Network: Write a batch. 298000 edges completed.
# Network: Write a batch. 300000 edges completed.
# Network: Write a batch. 302000 edges completed.
# Network: Write a batch. 304000 edges completed.
# Network: Write a batch. 306000 edges completed.
# Network: Write a batch. 308000 edges completed.
# Network: Write a batch. 310000 edges completed.
# Network: Write a batch. 312000 edges completed.
# Network: Write a batch. 314000 edges completed.
# Network: Write a batch. 316000 edges completed.
# Network: Write a batch. 318000 edges completed.
# Network: Write a batch. 320000 edges completed.
# Network: Write a batch. 322000 edges completed.
# Network: Write a batch. 324000 edges completed.
# Network: Write a batch. 326000 edges completed.
# Network: Write a batch. 328000 edges completed.
# Network: Write a batch. 330000 edges completed.
# Network: Write a batch. 332000 edges completed.
# Network: Write a batch. 334000 edges completed.
# Network: Write a batch. 336000 edges completed.
# Network: Write a batch. 338000 edges completed.
# Network: Write a batch. 340000 edges completed.
# Network: Write a batch. 342000 edges completed.
# Network: Write a batch. 344000 edges completed.
# Network: Write a batch. 346000 edges completed.
# Network: Write a batch. 348000 edges completed.
# Network: Write a batch. 350000 edges completed.
# Network: Write a batch. 352000 edges completed.
# Network: Write a batch. 354000 edges completed.
# Network: Write a batch. 356000 edges completed.
# Network: Write a batch. 358000 edges completed.
# Network: Write a batch. 360000 edges completed.
# Network: Write a batch. 362000 edges completed.
# Network: Write a batch. 364000 edges completed.
# Network: Write a batch. 366000 edges completed.
# Network: Write a batch. 368000 edges completed.
# Network: Write a batch. 370000 edges completed.
# Network: Write a batch. 372000 edges completed.
# Network: Write a batch. 374000 edges completed.
# Network: Write a batch. 376000 edges completed.
# Network: Write a batch. 378000 edges completed.
# Network: Write a batch. 380000 edges completed.
# Network: Write a batch. 382000 edges completed.
# Network: Write a batch. 384000 edges completed.
# Network: Write a batch. 386000 edges completed.
# Network: Write a batch. 388000 edges completed.
# Network: Write a batch. 390000 edges completed.
# Network: Write a batch. 392000 edges completed.
# Network: Write a batch. 394000 edges completed.
# Network: Write a batch. 396000 edges completed.
# Network: Write a batch. 398000 edges completed.
# Network: Write a batch. 400000 edges completed.
# Network: Write a batch. 402000 edges completed.
# Network: Write a batch. 404000 edges completed.
# Network: Write a batch. 406000 edges completed.
# Network: Write a batch. 408000 edges completed.
# Network: Write a batch. 410000 edges completed.
# Network: Write a batch. 412000 edges completed.
# Network: Write a batch. 414000 edges completed.
# Network: Write a batch. 416000 edges completed.
# Network: Write a batch. 418000 edges completed.
# Network: Write a batch. 420000 edges completed.
# Network: Write a batch. 422000 edges completed.
# Network: Write a batch. 424000 edges completed.
# Network: Write a batch. 426000 edges completed.
# Network: Write a batch. 428000 edges completed.
# Network: Write a batch. 430000 edges completed.
# Network: Write a batch. 432000 edges completed.
# Network: Write a batch. 434000 edges completed.
# Network: Write a batch. 436000 edges completed.
# Network: Write a batch. 438000 edges completed.
# Network: Write a batch. 440000 edges completed.
# Network: Write a batch. 442000 edges completed.
# Network: Write a batch. 444000 edges completed.
# Network: Write a batch. 446000 edges completed.
# Network: Write a batch. 448000 edges completed.
# Network: Write a batch. 450000 edges completed.
# Network: Write a batch. 452000 edges completed.
# Network: Write a batch. 454000 edges completed.
# Network: Write a batch. 456000 edges completed.
# Network: Write a batch. 458000 edges completed.
# Network: Write a batch. 460000 edges completed.
# Network: Write a batch. 462000 edges completed.
# Network: Write a batch. 464000 edges completed.
# Network: Write a batch. 466000 edges completed.
# Network: Write a batch. 468000 edges completed.
# Network: Write a batch. 470000 edges completed.
# Network: Write a batch. 472000 edges completed.
# Network: Write a batch. 474000 edges completed.
# Network: Write a batch. 476000 edges completed.
# Network: Write a batch. 478000 edges completed.
# Network: Write a batch. 480000 edges completed.
# Network: Write a batch. 482000 edges completed.
# Network: Write a batch. 484000 edges completed.
# Network: Write a batch. 486000 edges completed.
# Network: Write a batch. 488000 edges completed.
# Network: Write a batch. 490000 edges completed.
# Network: Write a batch. 492000 edges completed.
# Network: Write a batch. 494000 edges completed.
# Network: Write a batch. 496000 edges completed.
# Network: Write a batch. 498000 edges completed.
# Network: Write a batch. 500000 edges completed.
# Network: Write a batch. 502000 edges completed.
# Network: Write a batch. 504000 edges completed.
# Network: Write a batch. 506000 edges completed.
# Network: Write a batch. 508000 edges completed.
# Network: Write a batch. 510000 edges completed.
# Network: Write a batch. 512000 edges completed.
# Network: Write a batch. 514000 edges completed.
# Network: Write a batch. 516000 edges completed.
# Network: Write a batch. 518000 edges completed.
# Network: Write a batch. 520000 edges completed.
# Network: Write a batch. 522000 edges completed.
# Network: Write a batch. 524000 edges completed.
# Network: Write a batch. 526000 edges completed.
# Network: Write a batch. 528000 edges completed.
# Network: Write a batch. 530000 edges completed.
# Network: Write a batch. 532000 edges completed.
# Network: Write a batch. 534000 edges completed.
# Network: Write a batch. 536000 edges completed.
# Network: Write a batch. 538000 edges completed.
# Network: Write a batch. 540000 edges completed.
# Network: Write a batch. 542000 edges completed.
# Network: Write a batch. 544000 edges completed.
# Network: Write a batch. 546000 edges completed.
# Network: Write a batch. 548000 edges completed.
# Network: Write a batch. 550000 edges completed.
# Network: Write a batch. 552000 edges completed.
# Network: Write a batch. 554000 edges completed.
# Network: Write a batch. 556000 edges completed.
# Network: Write a batch. 558000 edges completed.
# Network: Write a batch. 560000 edges completed.
# Network: Write a batch. 562000 edges completed.
# Network: Write a batch. 564000 edges completed.
# Network: Write a batch. 566000 edges completed.
# Network: Write a batch. 568000 edges completed.
# Network: Write a batch. 570000 edges completed.
# Network: Write a batch. 572000 edges completed.
# Network: Write a batch. 574000 edges completed.
# Network: Write a batch. 576000 edges completed.
# Network: Write a batch. 578000 edges completed.
# Network: Write a batch. 580000 edges completed.
# Network: Write a batch. 582000 edges completed.
# Network: Write a batch. 584000 edges completed.
# Network: Write a batch. 586000 edges completed.
# Network: Write a batch. 588000 edges completed.
# Network: Write a batch. 590000 edges completed.
# Network: Write a batch. 592000 edges completed.
# Network: Write a batch. 594000 edges completed.
# Network: Write a batch. 596000 edges completed.
# Network: Write a batch. 598000 edges completed.
# Network: Write a batch. 600000 edges completed.
# Network: Write a batch. 602000 edges completed.
# Network: Write a batch. 604000 edges completed.
# Network: Write a batch. 606000 edges completed.
# Network: Write a batch. 608000 edges completed.
# Network: Write a batch. 610000 edges completed.
# Network: Write a batch. 612000 edges completed.
# Network: Write a batch. 614000 edges completed.
# Network: Write a batch. 616000 edges completed.
# Network: Write a batch. 618000 edges completed.
# Network: Write a batch. 620000 edges completed.
# Network: Write a batch. 622000 edges completed.
# Network: Write a batch. 624000 edges completed.
# Network: Write a batch. 626000 edges completed.
# Network: Write a batch. 628000 edges completed.
# Network: Write a batch. 630000 edges completed.
# Network: Write a batch. 632000 edges completed.
# Network: Write a batch. 634000 edges completed.
# Network: Write a batch. 636000 edges completed.
# Network: Write a batch. 638000 edges completed.
# Network: Write a batch. 640000 edges completed.
# Network: Write a batch. 642000 edges completed.
# Network: Write a batch. 644000 edges completed.
# Network: Write a batch. 646000 edges completed.
# Network: Write a batch. 648000 edges completed.
# Network: Write a batch. 650000 edges completed.
# Network: Write a batch. 652000 edges completed.
# Network: Write a batch. 654000 edges completed.
# Network: Write a batch. 656000 edges completed.
# Network: Write a batch. 658000 edges completed.
# Network: Write a batch. 660000 edges completed.
# Network: Write a batch. 662000 edges completed.
# Network: Write a batch. 664000 edges completed.
# Network: Write a batch. 666000 edges completed.
# Network: Write a batch. 668000 edges completed.
# Network: Write a batch. 670000 edges completed.
# Network: Write a batch. 672000 edges completed.
# Network: Write a batch. 674000 edges completed.
# Network: Write a batch. 676000 edges completed.
# Network: Write a batch. 678000 edges completed.
# Network: Write a batch. 680000 edges completed.
# Network: Write a batch. 682000 edges completed.
# Network: Write a batch. 684000 edges completed.
# Network: Write a batch. 686000 edges completed.
# Network: Write a batch. 688000 edges completed.
# Network: Write a batch. 690000 edges completed.
# Network: Write a batch. 692000 edges completed.
# Network: Write a batch. 694000 edges completed.
# Network: Write a batch. 696000 edges completed.
# Network: Write a batch. 698000 edges completed.
# Network: Write a batch. 700000 edges completed.
# Network: Write a batch. 702000 edges completed.
# Network: Write a batch. 704000 edges completed.
# Network: Write a batch. 706000 edges completed.
# Network: Write a batch. 708000 edges completed.
# Network: Write a batch. 710000 edges completed.
# Network: Write a batch. 712000 edges completed.
# Network: Write a batch. 714000 edges completed.
# Network: Write a batch. 716000 edges completed.
# Network: Write a batch. 718000 edges completed.
# Network: Write a batch. 720000 edges completed.
# Network: Write a batch. 722000 edges completed.
# Network: Write a batch. 724000 edges completed.
# Network: Write a batch. 726000 edges completed.
# Network: Write a batch. 728000 edges completed.
# Network: Write a batch. 730000 edges completed.
# Network: Write a batch. 732000 edges completed.
# Network: Write a batch. 734000 edges completed.
# Network: Write a batch. 736000 edges completed.
# Network: Write a batch. 738000 edges completed.
# Network: Write a batch. 740000 edges completed.
# Network: Write a batch. 742000 edges completed.
# Network: Write a batch. 744000 edges completed.
# Network: Write a batch. 746000 edges completed.
# Network: Write a batch. 748000 edges completed.
# Network: Write a batch. 750000 edges completed.
# Network: Write a batch. 752000 edges completed.
# Network: Write a batch. 754000 edges completed.
# Network: Write a batch. 756000 edges completed.
# Network: Write a batch. 758000 edges completed.
# Network: Write a batch. 760000 edges completed.
# Network: Write a batch. 762000 edges completed.
# Network: Write a batch. 764000 edges completed.
# Network: Write a batch. 766000 edges completed.
# Network: Write a batch. 768000 edges completed.
# Network: Write a batch. 770000 edges completed.
# Network: Write a batch. 772000 edges completed.
# Network: Write a batch. 774000 edges completed.
# Network: Write a batch. 776000 edges completed.
# Network: Write a batch. 778000 edges completed.
# Network: Write a batch. 780000 edges completed.
# Network: Write a batch. 782000 edges completed.
# Network: Write a batch. 784000 edges completed.
# Network: Write a batch. 786000 edges completed.
# Network: Write a batch. 788000 edges completed.
# Network: Write a batch. 790000 edges completed.
# Network: Write a batch. 792000 edges completed.
# Network: Write a batch. 794000 edges completed.
# Network: Write a batch. 796000 edges completed.
# Network: Write a batch. 798000 edges completed.
# Network: Write a batch. 800000 edges completed.
# Network: Write a batch. 802000 edges completed.
# Network: Write a batch. 804000 edges completed.
# Network: Write a batch. 806000 edges completed.
# Network: Write a batch. 808000 edges completed.
# Network: Write a batch. 810000 edges completed.
# Network: Write a batch. 812000 edges completed.
# Network: Write a batch. 814000 edges completed.
# Network: Write a batch. 816000 edges completed.
# Network: Write a batch. 818000 edges completed.
# Network: Write a batch. 820000 edges completed.
# Network: Write a batch. 822000 edges completed.
# Network: Write a batch. 824000 edges completed.
# Network: Write a batch. 826000 edges completed.
# Network: Write a batch. 828000 edges completed.
# Network: Write a batch. 830000 edges completed.
# Network: Write a batch. 832000 edges completed.
# Network: Write a batch. 834000 edges completed.
# Network: Write a batch. 836000 edges completed.
# Network: Write a batch. 838000 edges completed.
# Network: Write a batch. 840000 edges completed.
# Network: Write a batch. 842000 edges completed.
# Network: Write a batch. 844000 edges completed.
# Network: Write a batch. 846000 edges completed.
# Network: Write a batch. 848000 edges completed.
# Network: Write a batch. 850000 edges completed.
# Network: Write a batch. 852000 edges completed.
# Network: Write a batch. 854000 edges completed.
# Network: Write a batch. 856000 edges completed.
# Network: Write a batch. 858000 edges completed.
# Network: Write a batch. 860000 edges completed.
# Network: Write a batch. 862000 edges completed.
# Network: Write a batch. 864000 edges completed.
# Network: Write a batch. 866000 edges completed.
# Network: Write a batch. 868000 edges completed.
# Network: Write a batch. 870000 edges completed.
# Network: Write a batch. 872000 edges completed.
# Network: Write a batch. 874000 edges completed.
# Network: Write a batch. 876000 edges completed.
# Network: Write a batch. 878000 edges completed.
# Network: Write a batch. 880000 edges completed.
# Network: Write a batch. 882000 edges completed.
# Network: Write a batch. 884000 edges completed.
# Network: Write a batch. 886000 edges completed.
# Network: Write a batch. 888000 edges completed.
# Network: Write a batch. 890000 edges completed.
# Network: Write a batch. 892000 edges completed.
# Network: Write a batch. 894000 edges completed.
# Network: Write a batch. 896000 edges completed.
# Network: Write a batch. 898000 edges completed.
# Network: Write a batch. 900000 edges completed.
# Network: Write a batch. 902000 edges completed.
# Network: Write a batch. 904000 edges completed.
# Network: Write a batch. 906000 edges completed.
# Network: Write a batch. 908000 edges completed.
# Network: Write a batch. 910000 edges completed.
# Network: Write a batch. 912000 edges completed.
# Network: Write a batch. 914000 edges completed.
# Network: Write a batch. 916000 edges completed.
# Network: Write a batch. 918000 edges completed.
# Network: Write a batch. 920000 edges completed.
# Network: Write a batch. 922000 edges completed.
# Network: Write a batch. 924000 edges completed.
# Network: Write the last batch. 925872 edges completed.
# Network: All Done
# Result: Write a batch. 1000 nodes completed.
# Result: Write a batch. 2000 nodes completed.
# Result: Write a batch. 3000 nodes completed.
# Result: Write a batch. 4000 nodes completed.
# Result: Write a batch. 5000 nodes completed.
# Result: Write a batch. 6000 nodes completed.
# Result: Write a batch. 7000 nodes completed.
# Result: Write a batch. 8000 nodes completed.
# Result: Write a batch. 9000 nodes completed.
# Result: Write a batch. 10000 nodes completed.
# Result: Write a batch. 11000 nodes completed.
# Result: Write a batch. 12000 nodes completed.
# Result: Write a batch. 13000 nodes completed.
# Result: Write a batch. 14000 nodes completed.
# Result: Write a batch. 15000 nodes completed.
# Result: Write a batch. 16000 nodes completed.
# Result: Write a batch. 17000 nodes completed.
# Result: Write a batch. 18000 nodes completed.
# Result: Write a batch. 19000 nodes completed.
# Result: Write a batch. 20000 nodes completed.
# Result: Write a batch. 21000 nodes completed.
# Result: Write a batch. 22000 nodes completed.
# Result: Write a batch. 23000 nodes completed.
# Result: Write a batch. 24000 nodes completed.
# Result: Write a batch. 25000 nodes completed.
# Result: Write a batch. 26000 nodes completed.
# Result: Write a batch. 27000 nodes completed.
# Result: Write a batch. 28000 nodes completed.
# Result: Write a batch. 29000 nodes completed.
# Result: Write a batch. 30000 nodes completed.
# Result: Write a batch. 31000 nodes completed.
# Result: Write a batch. 32000 nodes completed.
# Result: Write a batch. 33000 nodes completed.
# Result: Write a batch. 34000 nodes completed.
# Result: Write a batch. 35000 nodes completed.
# Result: Write a batch. 36000 nodes completed.
# Result: Write a batch. 37000 nodes completed.
# Result: Write a batch. 38000 nodes completed.
# Result: Write a batch. 39000 nodes completed.
# Result: Write a batch. 40000 nodes completed.
# Result: Write a batch. 41000 nodes completed.
# Result: Write a batch. 42000 nodes completed.
# Result: Write a batch. 43000 nodes completed.
# Result: Write a batch. 44000 nodes completed.
# Result: Write a batch. 45000 nodes completed.
# Result: Write a batch. 46000 nodes completed.
# Result: Write a batch. 47000 nodes completed.
# Result: Write a batch. 48000 nodes completed.
# Result: Write a batch. 49000 nodes completed.
# Result: Write a batch. 50000 nodes completed.
# Result: Write a batch. 51000 nodes completed.
# Result: Write a batch. 52000 nodes completed.
# Result: Write a batch. 53000 nodes completed.
# Result: Write a batch. 54000 nodes completed.
# Result: Write a batch. 55000 nodes completed.
# Result: Write a batch. 56000 nodes completed.
# Result: Write a batch. 57000 nodes completed.
# Result: Write a batch. 58000 nodes completed.
# Result: Write a batch. 59000 nodes completed.
# Result: Write a batch. 60000 nodes completed.
# Result: Write a batch. 61000 nodes completed.
# Result: Write a batch. 62000 nodes completed.
# Result: Write a batch. 63000 nodes completed.
# Result: Write a batch. 64000 nodes completed.
# Result: Write a batch. 65000 nodes completed.
# Result: Write a batch. 66000 nodes completed.
# Result: Write a batch. 67000 nodes completed.
# Result: Write a batch. 68000 nodes completed.
# Result: Write a batch. 69000 nodes completed.
# Result: Write a batch. 70000 nodes completed.
# Result: Write a batch. 71000 nodes completed.
# Result: Write a batch. 72000 nodes completed.
# Result: Write a batch. 73000 nodes completed.
# Result: Write a batch. 74000 nodes completed.
# Result: Write a batch. 75000 nodes completed.
# Result: Write a batch. 76000 nodes completed.
# Result: Write a batch. 77000 nodes completed.
# Result: Write a batch. 78000 nodes completed.
# Result: Write a batch. 79000 nodes completed.
# Result: Write a batch. 80000 nodes completed.
# Result: Write a batch. 81000 nodes completed.
# Result: Write a batch. 82000 nodes completed.
# Result: Write a batch. 83000 nodes completed.
# Result: Write a batch. 84000 nodes completed.
# Result: Write a batch. 85000 nodes completed.
# Result: Write a batch. 86000 nodes completed.
# Result: Write a batch. 87000 nodes completed.
# Result: Write a batch. 88000 nodes completed.
# Result: Write a batch. 89000 nodes completed.
# Result: Write a batch. 90000 nodes completed.
# Result: Write a batch. 91000 nodes completed.
# Result: Write a batch. 92000 nodes completed.
# Result: Write a batch. 93000 nodes completed.
# Result: Write a batch. 94000 nodes completed.
# Result: Write a batch. 95000 nodes completed.
# Result: Write a batch. 96000 nodes completed.
# Result: Write a batch. 97000 nodes completed.
# Result: Write a batch. 98000 nodes completed.
# Result: Write a batch. 99000 nodes completed.
# Result: Write a batch. 100000 nodes completed.
# Result: Write a batch. 101000 nodes completed.
# Result: Write a batch. 102000 nodes completed.
# Result: Write a batch. 103000 nodes completed.
# Result: Write a batch. 104000 nodes completed.
# Result: Write a batch. 105000 nodes completed.
# Result: Write a batch. 106000 nodes completed.
# Result: Write a batch. 107000 nodes completed.
# Result: Write a batch. 108000 nodes completed.
# Result: Write a batch. 109000 nodes completed.
# Result: Write a batch. 110000 nodes completed.
# Result: Write a batch. 111000 nodes completed.
# Result: Write a batch. 112000 nodes completed.
# Result: Write a batch. 113000 nodes completed.
# Result: Write a batch. 114000 nodes completed.
# Result: Write a batch. 115000 nodes completed.
# Result: Write a batch. 116000 nodes completed.
# Result: Write a batch. 117000 nodes completed.
# Result: Write a batch. 118000 nodes completed.
# Result: Write a batch. 119000 nodes completed.
# Result: Write a batch. 120000 nodes completed.
# Result: Write a batch. 121000 nodes completed.
# Result: Write a batch. 122000 nodes completed.
# Result: Write a batch. 123000 nodes completed.
# Result: Write a batch. 124000 nodes completed.
# Result: Write a batch. 125000 nodes completed.
# Result: Write a batch. 126000 nodes completed.
# Result: Write a batch. 127000 nodes completed.
# Result: Write a batch. 128000 nodes completed.
# Result: Write a batch. 129000 nodes completed.
# Result: Write a batch. 130000 nodes completed.
# Result: Write a batch. 131000 nodes completed.
# Result: Write a batch. 132000 nodes completed.
# Result: Write a batch. 133000 nodes completed.
# Result: Write a batch. 134000 nodes completed.
# Result: Write a batch. 135000 nodes completed.
# Result: Write a batch. 136000 nodes completed.
# Result: Write a batch. 137000 nodes completed.
# Result: Write a batch. 138000 nodes completed.
# Result: Write a batch. 139000 nodes completed.
# Result: Write a batch. 140000 nodes completed.
# Result: Write a batch. 141000 nodes completed.
# Result: Write a batch. 142000 nodes completed.
# Result: Write a batch. 143000 nodes completed.
# Result: Write a batch. 144000 nodes completed.
# Result: Write a batch. 145000 nodes completed.
# Result: Write a batch. 146000 nodes completed.
# Result: Write a batch. 147000 nodes completed.
# Result: Write a batch. 148000 nodes completed.
# Result: Write a batch. 149000 nodes completed.
# Result: Write a batch. 150000 nodes completed.
# Result: Write a batch. 151000 nodes completed.
# Result: Write a batch. 152000 nodes completed.
# Result: Write a batch. 153000 nodes completed.
# Result: Write a batch. 154000 nodes completed.
# Result: Write a batch. 155000 nodes completed.
# Result: Write a batch. 156000 nodes completed.
# Result: Write a batch. 157000 nodes completed.
# Result: Write a batch. 158000 nodes completed.
# Result: Write a batch. 159000 nodes completed.
# Result: Write a batch. 160000 nodes completed.
# Result: Write a batch. 161000 nodes completed.
# Result: Write a batch. 162000 nodes completed.
# Result: Write a batch. 163000 nodes completed.
# Result: Write a batch. 164000 nodes completed.
# Result: Write a batch. 165000 nodes completed.
# Result: Write a batch. 166000 nodes completed.
# Result: Write a batch. 167000 nodes completed.
# Result: Write a batch. 168000 nodes completed.
# Result: Write a batch. 169000 nodes completed.
# Result: Write a batch. 170000 nodes completed.
# Result: Write a batch. 171000 nodes completed.
# Result: Write a batch. 172000 nodes completed.
# Result: Write a batch. 173000 nodes completed.
# Result: Write a batch. 174000 nodes completed.
# Result: Write a batch. 175000 nodes completed.
# Result: Write a batch. 176000 nodes completed.
# Result: Write a batch. 177000 nodes completed.
# Result: Write a batch. 178000 nodes completed.
# Result: Write a batch. 179000 nodes completed.
# Result: Write a batch. 180000 nodes completed.
# Result: Write a batch. 181000 nodes completed.
# Result: Write a batch. 182000 nodes completed.
# Result: Write a batch. 183000 nodes completed.
# Result: Write a batch. 184000 nodes completed.
# Result: Write a batch. 185000 nodes completed.
# Result: Write a batch. 186000 nodes completed.
# Result: Write a batch. 187000 nodes completed.
# Result: Write a batch. 188000 nodes completed.
# Result: Write a batch. 189000 nodes completed.
# Result: Write a batch. 190000 nodes completed.
# Result: Write a batch. 191000 nodes completed.
# Result: Write a batch. 192000 nodes completed.
# Result: Write a batch. 193000 nodes completed.
# Result: Write a batch. 194000 nodes completed.
# Result: Write a batch. 195000 nodes completed.
# Result: Write a batch. 196000 nodes completed.
# Result: Write a batch. 197000 nodes completed.
# Result: Write a batch. 198000 nodes completed.
# Result: Write a batch. 199000 nodes completed.
# Result: Write a batch. 200000 nodes completed.
# Result: Write a batch. 201000 nodes completed.
# Result: Write a batch. 202000 nodes completed.
# Result: Write a batch. 203000 nodes completed.
# Result: Write a batch. 204000 nodes completed.
# Result: Write a batch. 205000 nodes completed.
# Result: Write a batch. 206000 nodes completed.
# Result: Write a batch. 207000 nodes completed.
# Result: Write a batch. 208000 nodes completed.
# Result: Write a batch. 209000 nodes completed.
# Result: Write a batch. 210000 nodes completed.
# Result: Write a batch. 211000 nodes completed.
# Result: Write a batch. 212000 nodes completed.
# Result: Write a batch. 213000 nodes completed.
# Result: Write a batch. 214000 nodes completed.
# Result: Write a batch. 215000 nodes completed.
# Result: Write a batch. 216000 nodes completed.
# Result: Write a batch. 217000 nodes completed.
# Result: Write a batch. 218000 nodes completed.
# Result: Write a batch. 219000 nodes completed.
# Result: Write a batch. 220000 nodes completed.
# Result: Write a batch. 221000 nodes completed.
# Result: Write a batch. 222000 nodes completed.
# Result: Write a batch. 223000 nodes completed.
# Result: Write a batch. 224000 nodes completed.
# Result: Write a batch. 225000 nodes completed.
# Result: Write a batch. 226000 nodes completed.
# Result: Write a batch. 227000 nodes completed.
# Result: Write a batch. 228000 nodes completed.
# Result: Write a batch. 229000 nodes completed.
# Result: Write a batch. 230000 nodes completed.
# Result: Write a batch. 231000 nodes completed.
# Result: Write a batch. 232000 nodes completed.
# Result: Write a batch. 233000 nodes completed.
# Result: Write a batch. 234000 nodes completed.
# Result: Write a batch. 235000 nodes completed.
# Result: Write a batch. 236000 nodes completed.
# Result: Write a batch. 237000 nodes completed.
# Result: Write a batch. 238000 nodes completed.
# Result: Write a batch. 239000 nodes completed.
# Result: Write a batch. 240000 nodes completed.
# Result: Write a batch. 241000 nodes completed.
# Result: Write a batch. 242000 nodes completed.
# Result: Write a batch. 243000 nodes completed.
# Result: Write a batch. 244000 nodes completed.
# Result: Write a batch. 245000 nodes completed.
# Result: Write a batch. 246000 nodes completed.
# Result: Write a batch. 247000 nodes completed.
# Result: Write a batch. 248000 nodes completed.
# Result: Write a batch. 249000 nodes completed.
# Result: Write a batch. 250000 nodes completed.
# Result: Write a batch. 251000 nodes completed.
# Result: Write a batch. 252000 nodes completed.
# Result: Write a batch. 253000 nodes completed.
# Result: Write a batch. 254000 nodes completed.
# Result: Write a batch. 255000 nodes completed.
# Result: Write a batch. 256000 nodes completed.
# Result: Write a batch. 257000 nodes completed.
# Result: Write a batch. 258000 nodes completed.
# Result: Write a batch. 259000 nodes completed.
# Result: Write a batch. 260000 nodes completed.
# Result: Write a batch. 261000 nodes completed.
# Result: Write a batch. 262000 nodes completed.
# Result: Write a batch. 263000 nodes completed.
# Result: Write a batch. 264000 nodes completed.
# Result: Write a batch. 265000 nodes completed.
# Result: Write a batch. 266000 nodes completed.
# Result: Write a batch. 267000 nodes completed.
# Result: Write a batch. 268000 nodes completed.
# Result: Write a batch. 269000 nodes completed.
# Result: Write a batch. 270000 nodes completed.
# Result: Write a batch. 271000 nodes completed.
# Result: Write a batch. 272000 nodes completed.
# Result: Write a batch. 273000 nodes completed.
# Result: Write a batch. 274000 nodes completed.
# Result: Write a batch. 275000 nodes completed.
# Result: Write a batch. 276000 nodes completed.
# Result: Write a batch. 277000 nodes completed.
# Result: Write a batch. 278000 nodes completed.
# Result: Write a batch. 279000 nodes completed.
# Result: Write a batch. 280000 nodes completed.
# Result: Write a batch. 281000 nodes completed.
# Result: Write a batch. 282000 nodes completed.
# Result: Write a batch. 283000 nodes completed.
# Result: Write a batch. 284000 nodes completed.
# Result: Write a batch. 285000 nodes completed.
# Result: Write a batch. 286000 nodes completed.
# Result: Write a batch. 287000 nodes completed.
# Result: Write a batch. 288000 nodes completed.
# Result: Write a batch. 289000 nodes completed.
# Result: Write a batch. 290000 nodes completed.
# Result: Write a batch. 291000 nodes completed.
# Result: Write a batch. 292000 nodes completed.
# Result: Write a batch. 293000 nodes completed.
# Result: Write a batch. 294000 nodes completed.
# Result: Write a batch. 295000 nodes completed.
# Result: Write a batch. 296000 nodes completed.
# Result: Write a batch. 297000 nodes completed.
# Result: Write a batch. 298000 nodes completed.
# Result: Write a batch. 299000 nodes completed.
# Result: Write a batch. 300000 nodes completed.
# Result: Write a batch. 301000 nodes completed.
# Result: Write a batch. 302000 nodes completed.
# Result: Write a batch. 303000 nodes completed.
# Result: Write a batch. 304000 nodes completed.
# Result: Write a batch. 305000 nodes completed.
# Result: Write a batch. 306000 nodes completed.
# Result: Write a batch. 307000 nodes completed.
# Result: Write a batch. 308000 nodes completed.
# Result: Write a batch. 309000 nodes completed.
# Result: Write a batch. 310000 nodes completed.
# Result: Write a batch. 311000 nodes completed.
# Result: Write a batch. 312000 nodes completed.
# Result: Write a batch. 313000 nodes completed.
# Result: Write a batch. 314000 nodes completed.
# Result: Write a batch. 315000 nodes completed.
# Result: Write a batch. 316000 nodes completed.
# Result: Write a batch. 317000 nodes completed.
# Result: Write a batch. 318000 nodes completed.
# Result: Write a batch. 319000 nodes completed.
# Result: Write a batch. 320000 nodes completed.
# Result: Write a batch. 321000 nodes completed.
# Result: Write a batch. 322000 nodes completed.
# Result: Write a batch. 323000 nodes completed.
# Result: Write a batch. 324000 nodes completed.
# Result: Write a batch. 325000 nodes completed.
# Result: Write a batch. 326000 nodes completed.
# Result: Write a batch. 327000 nodes completed.
# Result: Write a batch. 328000 nodes completed.
# Result: Write a batch. 329000 nodes completed.
# Result: Write a batch. 330000 nodes completed.
# Result: Write a batch. 331000 nodes completed.
# Result: Write a batch. 332000 nodes completed.
# Result: Write a batch. 333000 nodes completed.
# Result: Write a batch. 334000 nodes completed.
# Result: Write the last batch. 334863 nodes completed.
# Result: All Done
# Running Time: 948.033s
